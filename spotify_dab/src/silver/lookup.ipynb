# %%
array = [
    {
        "file":"DimArtist"
    },
    {
        "file":"DimDate"
    },
    {
        "file":"DimTrack"
    },
    {
        "file":"DimUser"
    },
    {
        "file":"FactStream"
    }
]

# %%
dbutils.jobs.taskValues.set(key = "output_datasets",value = array)
