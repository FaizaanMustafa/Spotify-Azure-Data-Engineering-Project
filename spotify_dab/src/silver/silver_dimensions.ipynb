# %%
dbutils.widgets.text('file','')

# %%
var1 = dbutils.widgets.get('file')

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.readStream.format('CloudFiles') \
                    .option("cloudFiles.format", "parquet") \
                    .option("cloudFiles.schemaLocation",f"abfss://silver@azadls1245.dfs.core.windows.net/checkpoint_{var1}") \
                    .load(f"abfss://bronze@azadls1245.dfs.core.windows.net/{var1}")

# %%
df.writeStream.format('delta').outputMode('append').option("checkpointLocation",f"abfss://silver@azadls1245.dfs.core.windows.net/checkpoint_{var1}").trigger(once = True).option('path',f'abfss://silver@azadls1245.dfs.core.windows.net/{var1}').toTable(f"spotify_prj.silver.{var1}")
